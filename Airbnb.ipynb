# %%
# !pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.0/670.0 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 11.9 MB/s eta 0:00:00
# ...

# %%
# !pip install pandas

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 22.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 18.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 50.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.0 MB/s eta 0:00:00
# ...

# %%
# !pip install streamlit-option-menu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 822.1/822.1 kB 9.2 MB/s eta 0:00:00
# ...

# %%
import pymongo
import pandas as pd
pd.set_option("display.max_columns",None)
import warnings
warnings.filterwarnings("ignore")
import csv
import streamlit as st
from streamlit_option_menu import option_menu

# %%
#Client= pymongo.MongoClient("mongodb+srv://vigneshsoccer:vigneshsoccer@airbnb.h2e5kgd.mongodb.net/")


#db= Client["sample_airbnb"]
#coll= db["listingsAndReviews"]

# %%
import pandas as pd
df = pd.read_csv("/content/sample_airbnb.listingsAndReviews.csv")

# Get the column names
#column_names = df.columns

# Get the column indices
#column_indices = list(range(len(column_names)))

# Create a dictionary mapping column names to their indices
#column_name_to_index_map = dict(zip(column_names, column_indices))

# Print the column name to index map
#print(column_name_to_index_map)

# %%
df
# Out:
#            _id                            listing_url  \
# 0     10009999  https://www.airbnb.com/rooms/10009999
# 1     10006546  https://www.airbnb.com/rooms/10006546
# 2     10057826  https://www.airbnb.com/rooms/10057826
# 3     10038496  https://www.airbnb.com/rooms/10038496
# 4     10082307  https://www.airbnb.com/rooms/10082307
# ...        ...                                    ...
# 5550   9614672   https://www.airbnb.com/rooms/9614672
# 5551   9691680   https://www.airbnb.com/rooms/9691680
# 5552   9759181   https://www.airbnb.com/rooms/9759181
# 5553   9765083   https://www.airbnb.com/rooms/9765083
# 5554   9853331   https://www.airbnb.com/rooms/9853331
#
#                                    name  \
# 0          Horto flat with small garden
# 1               Ribeira Charming Duplex
# 2                     Deluxe Loft Suite
# 3          Copacabana Apartment Posto 6
# 4            Double Room en-suite (307)
# ...                                 ...
# ...

# %%
df.shape
# Out:
# (5555, 3361)

# %%
df_filtered = df[['_id',"accommodates",'neighborhood_overview','address.government_area','address.market','address.country','address.country_code','host.host_id','host.host_name','host.host_is_superhost','host.host_location','host.host_neighbourhood','host.host_response_time',"number_of_reviews",'guests_included',"reviews_per_month",'room_type','bed_type','minimum_nights','maximum_nights','address.location.coordinates[0]' ,'address.location.coordinates[1]','price','bedrooms','beds','property_type','number_of_reviews','first_review','availability.availability_30','availability.availability_60','availability.availability_90','availability.availability_365']]

# %% [markdown]
# Filtering the required columns to Analyse

# %%
df_filtered.shape
# Out:
# (5555, 32)

# %%
df_filtered = df_filtered.rename({"neighborhood_overview":'neighbourhood',"address.location.type":"Location_type","host.host_location":"host_location","host.host_verifications[1]":"host_verification_2","host.host_verifications[0]":"host_verification_1","host.host_is_superhost":"host_is_superhost","host.host_name":"host_name","address.market":"city","address.government_area":'government_area',"address.suburb":"suburb","address.street":"street","images.thumbnail_url":"image","host.host_response_time":"host_response_time","_id ":"ID","host.host_id":"host_id","host.host_name ":"host_name","host.host_neighbourhood":"host_neighbourhood","address.country":"country","address.country_code":"country_code","availability.availability_30":"availability_30","availability.availability_60":"availability_60","availability.availability_90":"availability_90",'availability.availability_365':"availability_365","address.location.coordinates[0]":"Latitudes","address.location.coordinates[1]":"Longitudes"},axis="columns")

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   _id                 5555 non-null   int64
#  1   accommodates        5555 non-null   int64
#  2   neighbourhood       3314 non-null   object
#  3   government_area     5555 non-null   object
#  4   city                5549 non-null   object
#  5   country             5555 non-null   object
#  6   country_code        5555 non-null   object
#  7   host_id             5555 non-null   int64
#  8   host_name           5555 non-null   object
#  9   host_is_superhost   5555 non-null   bool
#  10  host_location       5547 non-null   object
#  11  host_neighbourhood  3632 non-null   object
#  12  host_response_time  4167 non-null   object
#  13  number_of_reviews   5555 non-null   int64
#  14  guests_included     5555 non-null   int64
# ...

# %% [markdown]
# **Eliminating null values**

# %%
df_filtered.isnull().sum()
# Out:
# _id                      0
# accommodates             0
# neighbourhood         2241
# government_area          0
# city                     6
# country                  0
# country_code             0
# host_id                  0
# host_name                0
# host_is_superhost        0
# host_location            8
# host_neighbourhood    1923
# host_response_time    1388
# number_of_reviews        0
# guests_included          0
# reviews_per_month     5461
# room_type                0
# bed_type                 0
# minimum_nights           0
# maximum_nights           0
# Latitudes                0
# Longitudes               0
# price                    0
# bedrooms                 5
# beds                    13
# property_type            0
# number_of_reviews        0
# first_review          1388
# availability_30          0
# availability_60          0
# availability_90          0
# availability_365         0
# dtype: int64

# %%
df_filtered["neighbourhood"].fillna(0, inplace=True)
df_filtered["host_neighbourhood"].fillna(0, inplace=True)
df_filtered["host_response_time"].fillna(0, inplace=True)
df_filtered["beds"].fillna(0, inplace=True)
df_filtered["bedrooms"].fillna(0, inplace=True)
df_filtered["city"].fillna(0, inplace=True)
df_filtered["first_review"].fillna(0, inplace=True)
df_filtered["host_location"].fillna(0, inplace=True)
df_filtered["host_location"].fillna(0, inplace=True)
df_filtered["reviews_per_month"].fillna(0, inplace=True)

# %%
df_filtered.isnull().sum()
# Out:
# _id                   0
# accommodates          0
# neighbourhood         0
# government_area       0
# city                  0
# country               0
# country_code          0
# host_id               0
# host_name             0
# host_is_superhost     0
# host_location         0
# host_neighbourhood    0
# host_response_time    0
# number_of_reviews     0
# guests_included       0
# reviews_per_month     0
# room_type             0
# bed_type              0
# minimum_nights        0
# maximum_nights        0
# Latitudes             0
# Longitudes            0
# price                 0
# bedrooms              0
# beds                  0
# property_type         0
# number_of_reviews     0
# first_review          0
# availability_30       0
# availability_60       0
# availability_90       0
# availability_365      0
# dtype: int64

# %%
df_filtered.dtypes
# Out:
# _id                     int64
# accommodates            int64
# neighbourhood          object
# government_area        object
# city                   object
# country                object
# country_code           object
# host_id                 int64
# host_name              object
# host_is_superhost        bool
# host_location          object
# host_neighbourhood     object
# host_response_time     object
# number_of_reviews       int64
# guests_included         int64
# reviews_per_month     float64
# room_type              object
# bed_type               object
# minimum_nights          int64
# maximum_nights          int64
# Latitudes             float64
# Longitudes            float64
# price                 float64
# bedrooms              float64
# beds                  float64
# property_type          object
# number_of_reviews       int64
# first_review           object
# availability_30         int64
# availability_60         int64
# availability_90         int64
# ...

# %%
# changing Data Types
df_filtered["price"]= df_filtered["price"].astype(str).astype(float)
df_filtered["bedrooms"]= df_filtered["bedrooms"].astype(str).astype(float).astype(int)
df_filtered["beds"]= df_filtered["beds"].astype(str).astype(float).astype(int)
df_filtered["host_response_time"].fillna("Not Specified",inplace= True)
df_filtered["reviews_per_month"]= df_filtered["reviews_per_month"].astype(str).astype(float).astype(int)

# %%
df_filtered.shape
# Out:
# (5555, 32)

# %%
df_filtered["country"].unique()
# Out:
# array(['Brazil', 'Portugal', 'United States', 'Hong Kong', 'Canada',
#        'Turkey', 'Spain', 'Australia', 'China'], dtype=object)

# %%
#Changing Date Time format
df_filtered["first_review"]=pd.to_datetime(df_filtered["first_review"])

# %%
df_amenities = df.iloc[0:5555,25:31]

# %%
df_amenities.dtypes
# Out:
# amenities[0]    object
# amenities[1]    object
# amenities[2]    object
# amenities[3]    object
# amenities[4]    object
# amenities[5]    object
# dtype: object

# %%
# Concatenate values from multiple columns into a single column separated by commas
df_amenities['Amenities'] = df_amenities[['amenities[0]', 'amenities[1]', 'amenities[2]', 'amenities[3]', 'amenities[4]', 'amenities[5]']].apply(lambda x: ', '.join(x.dropna().astype(str)), axis=1)

# %%
df_amenities
# Out:
#      amenities[0]           amenities[1] amenities[2]  \
# 0            Wifi  Wheelchair accessible      Kitchen
# 1              TV               Cable TV         Wifi
# 2              TV               Cable TV     Internet
# 3              TV               Cable TV     Internet
# 4              TV               Internet         Wifi
# ...           ...                    ...          ...
# 5550           TV               Cable TV     Internet
# 5551           TV               Cable TV     Internet
# 5552           TV               Cable TV     Internet
# 5553           TV               Internet         Wifi
# 5554           TV               Cable TV     Internet
#
#                   amenities[3]               amenities[4]  \
# 0     Free parking on premises            Smoking allowed
# 1                      Kitchen  Paid parking off premises
# 2                         Wifi           Air conditioning
# 3                         Wifi           Air conditioning
# ...

# %%
df_amenities=df_amenities.drop(["amenities[0]","amenities[1]","amenities[2]","amenities[3]","amenities[4]","amenities[5]"],axis="columns")

# %%
df_amenities = df_amenities.sort_values(by='Amenities')

# %% [markdown]
# **checking null values in aminities**

# %%
df_amenities.isnull().sum()
# Out:
# Amenities    0
# dtype: int64

# %% [markdown]
# ### **Merging two Data Frames in to a single DataFrame**

# %%
df_airbnb= pd.concat([df_filtered, df_amenities], axis=1)
df_airbnb
# Out:
#            _id  accommodates  \
# 0     10009999             4
# 1     10006546             8
# 2     10057826             4
# 3     10038496             4
# 4     10082307             2
# ...        ...           ...
# 5550   9614672             3
# 5551   9691680             2
# 5552   9759181             4
# 5553   9765083             2
# 5554   9853331             5
#
#                                           neighbourhood  \
# 0     This charming ground floor flat is located in ...
# 1     In the neighborhood of the river, you can find...
# 2     Greenpoint is an artsy Brooklyn neighborhood f...
# 3     Copacabana in the South zone is the district t...
# 4                                                     0
# ...                                                 ...
# 5550                                                  0
# 5551                                                  0
# 5552  Astoria is a vibrant neighborhood full of wond...
# ...

# %%
df_airbnb.to_csv("Airbnb_final.csv", index=False)

# %%
df_airbnb.shape
# Out:
# (5555, 33)

# %% [markdown]
# ### country wise data for Streamlit Dashboard

# %%
# Filtering Country wise data
us_listing = df_filtered.query('country_code == "US"').loc[:, ["city","property_type","price","accommodates","room_type","host_neighbourhood","Latitudes","Longitudes","number_of_reviews"]]
Aus_listing = df_filtered.query('country_code == "AU"').loc[:, ["city","property_type","price","accommodates","room_type","host_neighbourhood","Latitudes","Longitudes","number_of_reviews"]]
BR_listing = df_filtered.query('country_code == "BR"').loc[:, ["city","property_type","price","accommodates","room_type","host_neighbourhood","Latitudes","Longitudes","number_of_reviews"]]
PT_listing = df_filtered.query('country_code == "PT"').loc[:, ["city","property_type","price","accommodates","room_type","host_neighbourhood","Latitudes","Longitudes","number_of_reviews"]]
Hong_listing = df_filtered.query('country_code == "HK"').loc[:, ["city","property_type","price","accommodates","room_type","host_neighbourhood","Latitudes","Longitudes","number_of_reviews"]]
Canada_listing = df_filtered.query('country_code == "CA"').loc[:, ["city","property_type","price","accommodates","room_type","host_neighbourhood","Latitudes","Longitudes","number_of_reviews"]]
Turkey_listing = df_filtered.query('country_code == "TR"').loc[:, ["city","property_type","price","accommodates","room_type","host_neighbourhood","Latitudes","Longitudes","number_of_reviews"]]
Spain_listing = df_filtered.query('country_code == "ES"').loc[:, ["city","property_type","price","accommodates","room_type","host_neighbourhood","Latitudes","Longitudes","number_of_reviews"]]

# %%
us_listing.to_csv("US_Airbnb_final.csv", index=False)
Aus_listing.to_csv("AUS_Airbnb_final.csv", index=False)
Aus_listing.to_csv("AUS_Airbnb_final.csv", index=False)
BR_listing.to_csv("Brazil_Airbnb_final.csv", index=False)
PT_listing.to_csv("Portugal_Airbnb_final.csv", index=False)
Hong_listing.to_csv("Hong_Airbnb_final.csv", index=False)
Canada_listing.to_csv("Canada_Airbnb_final.csv", index=False)
Turkey_listing.to_csv("Turkey_Airbnb_final.csv", index=False)
Spain_listing.to_csv("Spain_Airbnb_final.csv", index=False)

# %%
# %%writefile Airbnb.py
import pandas as pd
import streamlit as st
from streamlit_option_menu import option_menu
pd.set_option('display.max_columns', None)
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image

st.set_page_config(layout= "wide")
st.markdown("""
    <h1 style='text-align: center; color: Black'>AIRBNB DATA ANALYSIS</h1>
    """, unsafe_allow_html=True)
st.write("")

st.markdown(f""" <style>.stApp {{
                        background:url("https://c8.alamy.com/comp/2M6RXCF/airbnb-rotated-logo-white-background-b-2M6RXCF.jpg");
                        background-size: cover}}
                     </style>""", unsafe_allow_html=True)

#Uploading CSV files
df_US= pd.read_csv("/content/US_Airbnb_final.csv")
df_Brazil= pd.read_csv("/content/Brazil_Airbnb_final.csv")
df_Canada= pd.read_csv("/content/Canada_Airbnb_final.csv")
df_Hong= pd.read_csv("/content/Hong_Airbnb_final.csv")
df_Port= pd.read_csv("/content/Portugal_Airbnb_final.csv")
df_Spain= pd.read_csv("/content/Spain_Airbnb_final.csv")
df_Turkey= pd.read_csv("/content/Turkey_Airbnb_final.csv")
df_Aus= pd.read_csv("/content/AUS_Airbnb_final.csv")
df_Air= pd.read_csv("/content/Airbnb_final.csv")


# select= option_menu("Explore", ["Home", "Data Exploration"],orientation="horizontal")
select = option_menu(
    menu_title = None,
    options = ["Home","Explore Data"],
    icons =["house","bar-chart"],orientation="horizontal")
if select == "Home":
  text_content = """
    <h2 style='text-align: center; color: Black;'>Welcome to my Airbnb data analysis project</h2>
    <p style='font-size: 18px; text-align: center; color: Black'>
In our project, we're diving deep into Airbnb's vast collection of listings to find useful information. We use a powerful tool called MongoDB Atlas to help us analyze and understand the data better. Our main goal is to learn how the Airbnb market works. First, we carefully clean and organize the data to make sure it's accurate and reliable. Then, we create interactive maps and graphs to visualize the data in a meaningful way. These visuals help us spot trends, patterns, and differences in things like prices, availability, and what guests prefer. We're not just exploring data; we're discovering insights that can help people make better decisions in the Airbnb world, like how to price their listings or where to focus their efforts. Join us on this journey as we use data and MongoDB Atlas to shed light on the Airbnb phenomenon!</p>
        """

  # Display the text using markdown function
  st.markdown(text_content, unsafe_allow_html=True)

def chats():
  st.write("Data Analysis in",country)
  df_1=a.groupby("property_type").agg({"price":"mean","property_type":"count"}).sort_values("price")
  prop_name=[]

  for group_name,group_data in df_1.iterrows():
    prop_name.append(group_name)
  df_1["property name"]=prop_name

  df_2=a.groupby("host_neighbourhood").agg({"price":"mean","host_neighbourhood":"count"}).sort_values("price")
  Nei_names=[]
  for grp_name,grp_data in df_2.iterrows():
    Nei_names.append(grp_name)
  df_2["Neighbourhood"]=Nei_names

  df3=a.groupby(["city", "property_type"]).size().reset_index(name='number_of_reviews')

  df4=a.groupby("room_type").size().reset_index(name='number_of_reviews')

  col1,col2=st.columns(2)
  with col1:
    fig = px.bar(df_1,x='property name', y='price',color='price',color_discrete_sequence=px.colors.diverging.BrBG,
                  title='Property Type with Average Price'
          )
    st.plotly_chart(fig, use_container_width=True)

  with col2:
    fig = px.bar(df_2,x='Neighbourhood', y='price',color='price',color_discrete_sequence=px.colors.diverging.BrBG,
                  title='Average Price with respect to Neighbourhood'
          )
    st.plotly_chart(fig, use_container_width=True)

  col1,col2=st.columns(2)
  with col1:
    fig = px.sunburst(a, path=['city', 'property_type'], values='number_of_reviews',
                    title='City and its Property Types')
    st.plotly_chart(fig, use_container_width=True)

  with col2:
    fig = px.bar(a, x='room_type', y='number_of_reviews',
             labels={'room_type': 'Room Type', 'number_of_reviews': 'Number of Reviews'},
             title='Room Type with Review')

    st.plotly_chart(fig, use_container_width=True)

if select == "Explore Data":
  country = st.selectbox("Select A Country To Analyse", ["United States", "Turkey", "Portugal", "Canada", "Brazil", "Hong Kong", "Spain", "Australia"])




  if country == "United States":
    a=df_US
    chats()
  elif country == "Brazil":
    a=df_Brazil
    chats()
  elif country == "Canada":
    a=df_Canada
    chats()
  elif country == "Hong Kong":
    a=df_Hong
    chats()
  elif country == "Portugal":
    a=df_Port
    chats()
  elif country == "Spain":
    a=df_Spain
    chats()
  elif country == "Turkey":
    a=df_Turkey
    chats()
  elif country == "Australia":
    a=df_Aus
    chats()
# Out:
# Writing Airbnb.py

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.16.203.48

# %%
! streamlit run Airbnb.py & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.16.203.48:8501
#
# npx: installed 22 in 7.758s
# your url is: https://fine-webs-switch.loca.lt
